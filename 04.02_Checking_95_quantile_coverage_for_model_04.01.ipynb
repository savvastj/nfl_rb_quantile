# %% [markdown]
# # Check the coverage (calibration) of the 95th quantile predictions
# ## If well calibrated we should expect about 95% of the true AV values to be less than or equal to the predictions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import LeaveOneGroupOut

from sklearn.metrics import make_scorer
from sklearn.externals import joblib

# %%
train_df = pd.read_csv("processed_data/rb_train_data.csv")

# %%
model = joblib.load("models/best_model_04.01.pkl")

# %%
# create yearly average rushing stats
rush_per_yr_cols = ["Rush_Att_per_Yr", "Rush_Yds_per_Yr", "Rush_TD_per_Yr"]
train_df[rush_per_yr_cols] = (train_df.loc[:, "Rush_Att":"Rush_TD"]
                                      .div(train_df.Col_Yrs_Played, axis=0)
                                      .fillna(0))

features = ["Rush_Att",
            "Rush_Yds",
            "Rush_TD",
            "Rush_Yds_per_Att",
            "Rush_Att_per_G",
            "Rush_Yds_per_G",
            "Rush_TD_per_G",
            "Rush_Att_per_Yr",
            "Rush_Yds_per_Yr",
            "Rush_TD_per_Yr",
            "Ht",
            "Wt",
            "Forty",
            "Vertical",
            "Bench",
            "Broad Jump",
            "Cone",
            "Shuttle"]

target = "AV"

X = train_df.loc[:, features]
y = train_df.loc[:, target]

# # get a dictionary with the season as the key and the associated
# # row indices as the values
year_grpby = train_df.groupby("Year")
year_grpby.grouper.label_info
logo = LeaveOneGroupOut()
cv = list(logo.split(X, y, year_grpby.grouper.label_info))

# %%
cv_predictions = cross_val_predict(model, X, y)

# %%
cv_predictions
# Out:
# array([19.78155117, 17.80615864, 15.65127059, 34.56283128, 34.04265026,
#        19.59786865, 18.26476762, 35.01079753, 26.45876458, 30.83540949,
#        34.7491766 , 19.6285507 , 23.98458821, 29.13051701, 20.43136373,
#        27.80202519, 26.49138404, 44.43180449, 20.49128828, 15.28588288,
#        20.24172751, 26.16544337, 28.00709943, 37.37875842, 22.48359939,
#        30.32641756, 20.5240252 , 19.65857356, 16.6266592 , 20.60072317,
#        16.7430104 , 21.75615452, 18.79590954, 15.25029668, 15.79251332,
#        32.6176077 , 46.59988567, 37.01514664, 21.1668025 , 21.67748509,
#        35.1150577 , 16.43710161, 22.5508128 , 15.79251332, 21.11618708,
#        34.24778595, 25.88655261, 43.64564373, 29.38790254, 23.53176116,
#        13.58927584, 33.32059211, 46.64399082, 16.74034942, 24.03007959,
#        22.81752287, 33.07297703, 30.86126002, 24.66926801, 16.15683494,
#        17.29416632, 20.43300986, 22.26327112, 31.29252052,  9.84037609,
#        14.7041954 , 33.32668638, 22.12829217, 22.17126681, 19.36358866,
#        20.69001906, 18.39493563, 11.97722765, 13.52032496, 13.25859502,
#        20.8206937 , 35.48138309, 38.68058465, 21.20998186, 34.92174491,
#        13.2214069 , 46.51548846, 41.18933711, 27.22247892, 21.4166549 ,
#        11.7400093 , 26.65129423, 21.22894461, 24.64570146, 30.60201561,
#        24.11868009, 14.53300222, 38.1738614 , 35.27350973, 32.44243448,
#        24.4479902 , 48.71683098, 17.0371626 , 26.07749193, 23.57533919,
#        19.3320289 , 27.56660458, 19.76201251, 12.25011918, 30.55423978,
#        21.88514621, 24.1716575 , 22.91829714, 32.20920428, 24.2790501 ,
#        34.37872683, 31.4450893 , 14.65451352,  6.47530757,  8.84478754,
#        37.81938107,  0.5496499 , 29.7087917 , 17.69485198, -2.58588477,
#        28.983799  , 26.56593206, 53.40816655, 47.68750237, 36.80336061,
#        31.01730833, 25.9347557 , 42.53597179, -0.19899316, 43.90178095,
#        20.68996639, 35.00530758, 17.83525034, 27.05219187,  3.39418578,
#         6.37242621, 43.61785981, 39.78552589, 49.13186053, 13.21654172,
#        18.36751202, 20.09128366, 22.05606929, 14.96104656, 45.35433316,
#        16.3667614 , 17.44169876, 16.81631405,  9.88544242, 29.55423459,
#        41.77294568,  9.96405586, 26.71276096, 16.3667614 , 33.66986119,
#        30.96944504, 24.62496313, 16.24110608,  4.13356959,  5.50880062,
#        24.89372559, 24.23201187, 28.6008073 , 41.12129385, 33.09684391,
#        27.76265488, 36.53087546, 33.33808903, 24.62353777, 25.59074541,
#        21.26332043,  2.96276165, 33.83863366, 40.72769792, 17.74755964,
#         4.02892657, 25.91829415, 26.72459351, 47.08499288, 12.54684936,
#        29.9926739 , 43.63976156, 19.38377938, 16.81002687, 24.27538716,
#         9.76244555, 41.60786478, 12.12822384, 52.16139319, 26.40724029,
#        17.48337169, 25.61602779, 26.19897478, 16.83108012, 25.78610115,
#        15.26171789, 26.57914777, 28.57084833, 46.52684464, 12.40998623,
#        25.2223557 , 11.45426525, 35.32304214, 41.18465591, 23.65894324,
#         8.96834034, 57.91608221, 40.2564818 ,  8.71746866,  3.55157179,
#        26.51344231, 40.48934899, 30.23310753, 42.53833613, 21.73294255,
#        11.65270322, 16.84600779, 35.96060408, 28.03058683, 19.41577382,
#        25.65769652, 43.87335478, 29.36159105, 30.51273634, 25.48047783,
#        47.89798487, 24.76702397, 31.53795697, 43.29255511, 34.18589234,
#        19.4470728 , 11.14745158, 61.43531055, 29.4671453 , 45.91900794,
#        20.21866424, 31.22605789, 20.96282498, 56.91936975, 26.47872021,
#        45.72707164, 55.2639039 , 41.1260753 , 46.08675018, 18.85485253,
#        23.6836438 , 26.29997842, -7.10025044, 47.85036601, 49.65170136,
#        22.88079249, 29.5921571 , 18.85485253, 20.95546987, 35.30027174,
#        30.38681167, 24.87478742, 29.63454316, 49.15411065, 19.6423259 ,
#        18.54992686, 29.02254605, 36.82870049, 41.1260753 , 21.8867152 ,
#        18.1910343 , 48.13311424, 40.39200026, 31.38407919, 34.4400456 ,
#        31.53795697, 58.58126826, 32.46085052, 16.30581396, 45.56663173,
#        16.82771653, 20.27734277, 12.86012663, 21.26121717, 13.32622638,
#        43.07345041, 30.52701879, 26.61512702, 11.77930839,  5.29711844,
#         9.36619546, 65.78618603, 46.06362762, 12.89072114, 37.44332271,
#        11.80583786,  4.98764931, 14.0153283 , 46.90256827, 29.71467902,
#        50.53473905, 23.93330996, 27.84916628, 19.40641598, 36.09351296,
#        10.37361562, 15.70412006, 28.76955748, 37.59142283, 22.31500336,
#        12.33824518, 47.65319623, 13.51581752, 27.87922362, 48.64704521,
#        34.97157595, 23.55236006, 40.87792933, 47.44441824, 30.28562125,
#        27.98377298, 37.85323854, 33.85065674, 38.39936794, 45.86820704,
#        20.64042342, 13.72380537, 31.53795697, 18.65450601, 38.41408469,
#        40.00521455, 34.41621118, 30.13448902, 55.23486038, 25.06421624,
#        17.5893404 , 28.46194577])

# %%
train_df['AV_95_pred'] = cv_predictions

# %%
train_df[['Player', 'AV_95_pred']].sort_values('AV_95_pred', ascending=False).head(25)
# Out:
#                   Player  AV_95_pred
# 286         Ryan Mathews   65.786186
# 232      Darren McFadden   61.435311
# 271         Beanie Wells   58.581268
# 206      Adrian Peterson   57.916082
# 238             Ray Rice   56.919370
# 241         Steve Slaton   55.263904
# 328        Jordan Todman   55.234860
# 122       Steven Jackson   53.408167
# 188    DeAngelo Williams   52.161393
# 295             Ben Tate   50.534739
# 249          Andre Brown   49.651701
# 258          Ian Johnson   49.154111
# 138        Cedric Benson   49.131861
# 96         Justin Fargas   48.716831
# 309         Mario Fannin   48.647045
# 266       Cedric Peerman   48.133114
# 225           Matt Forte   47.897985
# 248         Donald Brown   47.850366
# 123          Kevin Jones   47.687502
# 306          Noel Devine   47.653196
# 313       Kendall Hunter   47.444418
# 178     Laurence Maroney   47.084993
# 293         C.J. Spiller   46.902568
# 52   LaDainian Tomlinson   46.643991
# 36       Michael Bennett   46.599886

# %%
(train_df.AV <= train_df.AV_95_pred).sum() / train_df.shape[0]
# Out:
# 0.9096385542168675
