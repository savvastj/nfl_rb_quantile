# %%
import pfr
import pandas as pd

# %%
combine_df = pd.read_csv("raw_data/pfr_combine_data.csv")

# %%
combine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6218 entries, 0 to 6217
# Data columns (total 16 columns):
# Player                 6218 non-null object
# Pos                    6218 non-null object
# School                 6218 non-null object
# College                4841 non-null object
# Ht                     6218 non-null object
# Wt                     6218 non-null int64
# 40yd                   6046 non-null float64
# Vertical               4796 non-null float64
# Bench                  4212 non-null float64
# Broad Jump             4754 non-null float64
# 3Cone                  3993 non-null float64
# Shuttle                4063 non-null float64
# Drafted (tm/rnd/yr)    3892 non-null object
# Year                   6218 non-null int64
# Pfr_ID                 4895 non-null object
# Sref_Cfb_ID            4841 non-null object
# dtypes: float64(6), int64(2), object(8)
# memory usage: 777.3+ KB

# %%
combine_df.head()
# Out:
#              Player  Pos          School  \
# 0      John Abraham  OLB  South Carolina
# 1   Shaun Alexander   RB         Alabama
# 2    Darnell Alford   OT  Boston College
# 3      Kyle Allamon   TE      Texas Tech
# 4  Rashard Anderson   CB   Jackson State
#
#                                              College   Ht   Wt  40yd  \
# 0                                                NaN  6-4  252  4.55
# 1  https://www.sports-reference.com/cfb/players/s...  6-0  218  4.58
# 2                                                NaN  6-4  334  5.56
# 3                                                NaN  6-2  253  4.97
# 4                                                NaN  6-2  206  4.55
#
#    Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0       NaN    NaN         NaN    NaN      NaN
# 1       NaN    NaN         NaN    NaN      NaN
# 2      25.0   23.0        94.0   8.48     4.98
# 3      29.0    NaN       104.0   7.29     4.49
# 4      34.0    NaN       123.0   7.18     4.15
#
#                             Drafted (tm/rnd/yr)  Year    Pfr_ID  \
# 0        New York Jets / 1st / 13th pick / 2000  2000  AbraJo00
# 1     Seattle Seahawks / 1st / 19th pick / 2000  2000  AlexSh00
# 2  Kansas City Chiefs / 6th / 188th pick / 2000  2000  AlfoDa20
# 3                                           NaN  2000       NaN
# 4    Carolina Panthers / 1st / 23rd pick / 2000  2000  AndeRa21
#
#          Sref_Cfb_ID
# 0                NaN
# 1  shaun-alexander-1
# 2                NaN
# 3                NaN
# 4                NaN

# %%
combine_df.Pos.unique()
# Out:
# array(['OLB', 'RB', 'OT', 'TE', 'CB', 'K', 'P', 'FS', 'OG', 'ILB', 'DE',
#        'SS', 'DT', 'QB', 'WR', 'C', 'FB', 'LS', 'NT', 'EDGE', 'S', 'LB',
#        'DB', 'OL'], dtype=object)

# %%
# we just want RBs with Sref IDs
rb_df = combine_df.loc[(combine_df.Pos=='RB') & (combine_df.Sref_Cfb_ID.notnull())]

# %%
rb_df.head()
# Out:
#              Player Pos     School  \
# 1   Shaun Alexander  RB    Alabama
# 41   Trung Canidate  RB    Arizona
# 48     Doug Chapman  RB   Marshall
# 76        Ron Dayne  RB  Wisconsin
# 80  Reuben Droughns  RB     Oregon
#
#                                               College    Ht   Wt  40yd  \
# 1   https://www.sports-reference.com/cfb/players/s...   6-0  218  4.58
# 41  https://www.sports-reference.com/cfb/players/t...  5-11  193  4.41
# 48  https://www.sports-reference.com/cfb/players/d...  5-10  215  4.56
# 76  https://www.sports-reference.com/cfb/players/r...  5-11  259  4.65
# 80  https://www.sports-reference.com/cfb/players/r...  5-11  215  4.66
#
#     Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 1        NaN    NaN         NaN    NaN      NaN
# 41       NaN   18.0         NaN    NaN      NaN
# 48      38.5   16.0       128.0   6.84     4.20
# 76       NaN    NaN         NaN    NaN      NaN
# 80      30.0   13.0       115.0   7.34     4.41
#
#                            Drafted (tm/rnd/yr)  Year    Pfr_ID  \
# 1    Seattle Seahawks / 1st / 19th pick / 2000  2000  AlexSh00
# 41     St. Louis Rams / 1st / 31st pick / 2000  2000  CaniTr00
# 48  Minnesota Vikings / 3rd / 88th pick / 2000  2000  ChapDo00
# 76    New York Giants / 1st / 11th pick / 2000  2000  DaynRo00
# 80      Detroit Lions / 3rd / 81st pick / 2000  2000  DrouRe00
#
#           Sref_Cfb_ID
# 1   shaun-alexander-1
# 41   trung-canidate-1
# 48     doug-chapman-1
# 76        ron-dayne-1
# 80  reuben-droughns-1

# %%
rb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 479 entries, 1 to 6205
# Data columns (total 16 columns):
# Player                 479 non-null object
# Pos                    479 non-null object
# School                 479 non-null object
# College                479 non-null object
# Ht                     479 non-null object
# Wt                     479 non-null int64
# 40yd                   471 non-null float64
# Vertical               389 non-null float64
# Bench                  362 non-null float64
# Broad Jump             381 non-null float64
# 3Cone                  272 non-null float64
# Shuttle                275 non-null float64
# Drafted (tm/rnd/yr)    302 non-null object
# Year                   479 non-null int64
# Pfr_ID                 406 non-null object
# Sref_Cfb_ID            479 non-null object
# dtypes: float64(6), int64(2), object(8)
# memory usage: 63.6+ KB

# %% [markdown]
# # Scrape the data

# %%
# columns for scraped data
basic_cols = ["Year", "School", "Conf", "Class", "Pos", "G"]
rush_cols = ["Rush_Att", "Rush_Yds", "Rush_Avg", "Rush_TD"]
rec_cols = ["Rec", "Rec_Yds", "Rec_Avg", "Rec_TD"]
scrim_cols = ["Plays", "Scrim_Yds", "Scrim_Avg", "Scrim_TD"]
col_dict = {"rush_cols": basic_cols + rush_cols + rec_cols + scrim_cols,
            "rec_cols": basic_cols + rec_cols + rush_cols + scrim_cols}

# %%
# set up data structures to store scraped data
dfs = []
errors = []
url_template = "https://www.sports-reference.com/cfb/players/{}.html"

# %%
for player_id in rb_df.Sref_Cfb_ID:
    url = url_template.format(player_id)
    pq_obj = pfr.create_pq(url)
    try:
        # scrape the rushing data
        rush_data = pfr.get_row_data(pq_obj,"#rushing > tbody > tr")
        rush_df = pd.DataFrame(rush_data, columns=col_dict["rush_cols"])

        # if df isn't empty then there is a rushing table on the page
        # so lets add the player id and append
        if rush_df.shape[0] > 0: 
            rush_df["Sref_Cfb_ID"] = player_id
            dfs.append(rush_df)

        # otherwis, when rush_df is empty scrape data using #receiving
        # selector
        else:
            rec_data = pfr.get_row_data(pq_obj, "#receiving > tbody > tr")
            rec_df = pd.DataFrame(rec_data, columns=col_dict["rec_cols"])
            rec_df["Sref_Cfb_ID"] = player_id
            dfs.append(rec_df)
        print("Sraped:", player_id)
    except Exception as e:
        errors.append([player_id, url, e])
        print("ERROR:", player_id)
# Out:
# Sraped: shaun-alexander-1
# Sraped: trung-canidate-1
# Sraped: doug-chapman-1
# Sraped: ron-dayne-1
# Sraped: reuben-droughns-1
# Sraped: troy-hambrick-1
# Sraped: ronney-jenkins-1
# Sraped: thomas-jones-1
# Sraped: curtis-keaton-1
# Sraped: jamal-lewis-2
# Sraped: kevin-mcdougal-2
# Sraped: rondell-mealey-1
# Sraped: frank-moreau-1
# Sraped: chad-morton-1
# Sraped: travis-prentice-1
# Sraped: jr-redmond-1
# Sraped: shyrone-stith-1
# Sraped: michael-wiley-1
# Sraped: david-allen-1
# Sraped: kevan-barlow-1
# Sraped: michael-bennett-1
# Sraped: correll-buckhalter-1
# Sraped: jeff-chaney-1
# Sraped: derek-combs-1
# Sraped: travis-henry-1
# Sraped: derek-homer-1
# Sraped: james-jackson-1
# Sraped: rudi-johnson-1
# Sraped: lamont-jordan-1
# Sraped: deuce-mcallister-1
# Sraped: travis-minor-1
# Sraped: hodges-mitchell-1
# Sraped: anthony-thomas-2
# Sraped: ladainian-tomlinson-1
# Sraped: reggie-white-1
# Sraped: jonathan-adams-1
# Sraped: brian-allen-2
# Sraped: damien-anderson-1
# Sraped: ladell-betts-1
# Sraped: joe-burns-1
# Sraped: demontray-carter-2
# Sraped: rod-cartwright-1
# Sraped: eric-crouch-1
# Sraped: tj-duckett-1
# Sraped: tony-fisher-1
# Sraped: little-john-flowers-1
# Sraped: delvon-flowers-1
# Sraped: deshaun-foster-1
# Sraped: william-green-1
# Sraped: ennis-haywood-1
# Sraped: leonard-henry-1
# Sraped: dameon-hunter-1
# Sraped: eric-mccoo-1
# Sraped: dicenzo-miller-1
# Sraped: dave-minnich-1
# Sraped: maurice-morris-1
# Sraped: larry-ned-1
# Sraped: clinton-portis-1
# Sraped: tellis-redmon-1
# Sraped: josh-scobey-1
# Sraped: luke-staley-1
# Sraped: travis-stephens-1
# Sraped: chester-taylor-1
# Sraped: lew-thomas-1
# Sraped: jonathan-wells-1
# Sraped: levron-williams-1
# Sraped: ricky-williams-2
# Sraped: bj-askew-1
# Sraped: santonio-beard-1
# Sraped: chris-brown-1
# Sraped: kerry-carter-1
# Sraped: avon-cobourne-1
# Sraped: dahrran-diedrick-1
# Sraped: justin-fargas-1
# Sraped: ahmaad-galloway-1
# Sraped: earnest-graham-1
# Sraped: quentin-griffin-1
# Sraped: dwone-hicks-1
# Sraped: larry-johnson-1
# Sraped: malaefou-mackenzie-1
# Sraped: nick-maddox-1
# Sraped: sultan-mccullough-1
# Sraped: willis-mcgahee-1
# Sraped: artose-pinner-1
# Sraped: cecil-sapp-1
# Sraped: musa-smith-1
# Sraped: onterrio-smith-1
# Sraped: lee-suggs-1
# Sraped: labrandon-toefield-1
# Sraped: domanick-davis-1
# Sraped: jahwan-edwards-1
# Sraped: melvin-gordon-1
# Sraped: todd-gurley-1
# Sraped: dee-hart-1
# Sraped: braylon-heard-1
# Sraped: kenny-hilliard-1
# Sraped: duke-johnson-1
# Sraped: matt-jones-3
# Sraped: jeremy-langford-1
# Sraped: terrence-magee-1
# Sraped: marcus-murphy-1
# Sraped: thomas-rawls-1
# Sraped: josh-robinson-2
# Sraped: karlos-williams-1
# Sraped: trey-williams-2
# Sraped: tj-yeldon-1
# Sraped: peyton-barber-1
# Sraped: devontae-booker-1
# Sraped: tra-carson-1
# Sraped: alex-collins-1
# Sraped: kenneth-dixon-1
# Sraped: kenyan-drake-1
# Sraped: ezekiel-elliott-1
# Sraped: tyler-ervin-1
# Sraped: josh-ferguson-3
# Sraped: derrick-henry-2
# Sraped: jordan-howard-1
# Sraped: devon-johnson-1
# Sraped: daniel-lasco-1
# Sraped: tre-madden-1
# Sraped: keith-marshall-1
# Sraped: paul-perkins-1
# Sraped: cj-prosise-1
# Sraped: wendell-smallwood-1
# Sraped: kelvin-taylor-1
# Sraped: shadrach-thornton-1
# Sraped: deandre-washington-1
# Sraped: brandon-wilds-1
# Sraped: jonathan-williams-2
# Sraped: chris-carson-1
# Sraped: corey-clement-1
# Sraped: james-conner-1
# Sraped: dalvin-cook-1
# Sraped: justin-davis-2
# Sraped: matt-dayes-1
# Sraped: donta-foreman-1
# Sraped: leonard-fournette-1
# Sraped: wayne-gallman-1
# Sraped: brian-hill-4
# Sraped: elijah-hood-1
# Sraped: kareem-hunt-1
# Sraped: rushel-shell-3
# Sraped: aaron-jones-6
# Sraped: alvin-kamara-1
# Sraped: tj-logan-1
# Sraped: marlon-mack-1
# Sraped: christian-mccaffrey-1
# Sraped: elijah-mcguire-1
# Sraped: jeremy-mcnichols-1
# Sraped: dare-ogunbowale-1
# Sraped: samaje-perine-1
# Sraped: donnel-pumphrey-1
# Sraped: devine-redding-1
# Sraped: deveon-smith-1
# Sraped: jahad-thomas-1
# Sraped: stanley-boom-williams-1
# Sraped: joe-williams-7
# Sraped: jamaal-williams-1
# Sraped: josh-adams-2
# Sraped: kalen-ballage-1
# Sraped: saquon-barkley-1
# Sraped: nick-chubb-1
# Sraped: lavon-coleman-1
# Sraped: justin-crawford-1
# Sraped: dmitri-flowers-1
# Sraped: jarvion-franklin-1
# Sraped: royce-freeman-1
# Sraped: derrius-guice-1
# Sraped: kyle-hicks-1
# Sraped: nyheim-hines-1
# Sraped: justin-jackson-5
# Sraped: kerryon-johnson-1
# Sraped: ronald-jones-4
# Sraped: john-kelly-6
# Sraped: sony-michel-1
# Sraped: ryan-nail-1
# Sraped: rashaad-penny-1
# Sraped: kamryn-pettway-1
# Sraped: bo-scarbrough-1
# Sraped: akrum-wadley-1
# Sraped: mark-walton-1
# Sraped: jordan-wilkins-1
# Sraped: darrel-williams-1

# %%
errors
# Out:
# []

# %%
len(dfs)
# Out:
# 479

# %%
len(errors)
# Out:
# 0

# %% [markdown]
# # Set up the rushing and receiving data

# %%
rush_rec_df = pd.concat(dfs, ignore_index=True, sort=False)

# %%
rush_rec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 19 columns):
# Year           1671 non-null object
# School         1671 non-null object
# Conf           1671 non-null object
# Class          1671 non-null object
# Pos            1671 non-null object
# G              1671 non-null object
# Rush_Att       1671 non-null object
# Rush_Yds       1671 non-null object
# Rush_Avg       1671 non-null object
# Rush_TD        1671 non-null object
# Rec            1671 non-null object
# Rec_Yds        1671 non-null object
# Rec_Avg        1671 non-null object
# Rec_TD         1671 non-null object
# Plays          1671 non-null object
# Scrim_Yds      1671 non-null object
# Scrim_Avg      1671 non-null object
# Scrim_TD       1671 non-null object
# Sref_Cfb_ID    1671 non-null object
# dtypes: object(19)
# memory usage: 248.1+ KB

# %%
rush_rec_df.to_csv("raw_data/rb_yearly_college_rush_rec_stats.csv",
                   index=False)

# %%
# some seasons contain bowl game stats, should have a column indicating that
rush_rec_df["Stats_Incl_Bowl_Gm"] = rush_rec_df.Year.str.contains("\*").astype(int)

# %%
# now get rid of * symbol
rush_rec_df.loc[:, "Year"] = rush_rec_df.Year.str.strip("\*").astype(int)

# %%
rush_rec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 20 columns):
# Year                  1671 non-null int64
# School                1671 non-null object
# Conf                  1671 non-null object
# Class                 1671 non-null object
# Pos                   1671 non-null object
# G                     1671 non-null object
# Rush_Att              1671 non-null object
# Rush_Yds              1671 non-null object
# Rush_Avg              1671 non-null object
# Rush_TD               1671 non-null object
# Rec                   1671 non-null object
# Rec_Yds               1671 non-null object
# Rec_Avg               1671 non-null object
# Rec_TD                1671 non-null object
# Plays                 1671 non-null object
# Scrim_Yds             1671 non-null object
# Scrim_Avg             1671 non-null object
# Scrim_TD              1671 non-null object
# Sref_Cfb_ID           1671 non-null object
# Stats_Incl_Bowl_Gm    1671 non-null int64
# dtypes: int64(2), object(18)
# memory usage: 261.2+ KB

# %%
rush_rec_df.head()
# Out:
#    Year   School    Conf Class Pos   G Rush_Att Rush_Yds Rush_Avg Rush_TD Rec  \
# 0  1996  Alabama     SEC        RB  11       77      589      7.6       6   7
# 1  1997  Alabama     SEC        RB   9       90      415      4.6       3   4
# 2  1998  Alabama     SEC        RB  11      258     1178      4.6      13  26
# 3  1999  Alabama     SEC        RB  11      302     1383      4.6      19  25
# 4  1996  Arizona  Pac-10        WR  11
#
#   Rec_Yds Rec_Avg Rec_TD Plays Scrim_Yds Scrim_Avg Scrim_TD  \
# 0      53     7.6      0    84       642       7.6        6
# 1      37     9.3      0    94       452       4.8        3
# 2     385    14.8      4   284      1563       5.5       17
# 3     323    12.9      4   327      1706       5.2       23
# 4                            0         0                  0
#
#          Sref_Cfb_ID  Stats_Incl_Bowl_Gm
# 0  shaun-alexander-1                   0
# 1  shaun-alexander-1                   0
# 2  shaun-alexander-1                   0
# 3  shaun-alexander-1                   0
# 4   trung-canidate-1                   0

# %%
rush_rec_df.to_csv("processed_data/rb_yearly_college_rush_rec_stats.csv",
                   index=False)
